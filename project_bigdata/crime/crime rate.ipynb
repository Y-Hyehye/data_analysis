# %%
import pandas as pd

# %%
df=pd.read_csv('crime.csv', encoding='cp949')

# %%
df_=pd.read_csv('safety_bell.csv', encoding='cp949')

# %%
df
# Out:
#      범죄대분류      범죄중분류     서울     부산     대구     인천     광주     대전     울산    세종  \
# 0     강력범죄       살인기수     50     21     16     11      3      8      5     1
# 1     강력범죄      살인미수등     91     41     30     24      6     14     12     5
# 2     강력범죄         강도    167    102     37     73     33     41     25     3
# 3     강력범죄         강간   1155    334    201    352    203    176     97    17
# 4     강력범죄       유사강간    144     43     26     44     23     33      2     0
# 5     강력범죄       강제추행   5582   1282    610   1282    490    481    302    53
# 6     강력범죄  기타강간강제추행등     60     23      8     13     10      9      9     2
# 7     강력범죄         방화    225     90     71     81     35     37     33     3
# 8     절도범죄         절도  41144  15807   8310   9216   4821   6216   3578   582
# 9     폭력범죄         상해   6016   4220   2781   2074   1171   1165   1409   152
# 10    폭력범죄         폭행  36312  10174   6885  11586   4856   5256   3863   285
# ...

# %%
df_
# Out:
#       안전비상벨관리번호  설치목적  설치장소유형               설치위치                소재지도로명주소  \
# 0             1     1       2         신채호선생생가 공원    대전광역시 중구 단재로229번길 29
# 1             2     1       2             농촌테마마을   대전광역시 중구 운남로85번길 32-8
# 2             3     1       2  으능정이고객 지원센터 건물 1층         대전광역시 중구 중교로 83
# 3             4     1       2    청소년문화마당광장내 건물1층  대전광역시 중구 선화로119번길 16-3
# 4             5     1       2               목척시장       대전광역시 중구 목척5길 126
# ...         ...   ...     ...                ...                     ...
# 31886   2081401    99       1           경산자연마당입구                     NaN
# 31887   2081501     2       5            모듬막구이건너                     NaN
# 31888   2081601     2       5            정원고기마을앞                     NaN
# 31889   2081701     2       5         삼성현유치원앞삼거리                     NaN
# 31890   2081801     2       5          피아노이야기건너편                     NaN
#
#                        소재지지번주소         위도          경도  연계방식 경찰연계유무  ...  \
# ...

# %%
df.shape
# Out:
# (38, 89)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 89 columns):
# 범죄대분류     38 non-null object
# 범죄중분류     38 non-null object
# 서울        38 non-null int64
# 부산        38 non-null int64
# 대구        38 non-null int64
# 인천        38 non-null int64
# 광주        38 non-null int64
# 대전        38 non-null int64
# 울산        38 non-null int64
# 세종        38 non-null int64
# 경기 고양     38 non-null int64
# 경기 과천     38 non-null int64
# 경기 광명     38 non-null int64
# 경기 광주     38 non-null int64
# 경기 구리     38 non-null int64
# 경기 군포     38 non-null int64
# 경기 김포     38 non-null int64
# 경기 남양주    38 non-null int64
# 경기 동두천    38 non-null int64
# 경기 부천     38 non-null int64
# 경기 성남     38 non-null int64
# 경기 수원     38 non-null int64
# 경기 시흥     38 non-null int64
# 경기 안산     38 non-null int64
# 경기 안성     38 non-null int64
# 경기 안양     38 non-null int64
# 경기 양주     38 non-null int64
# 경기 여주     38 non-null int64
# 경기 오산     38 non-null int64
# ...

# %%
df.describe()
# Out:
#                  서울            부산            대구            인천            광주  \
# count     38.000000     38.000000     38.000000     38.000000     38.000000
# mean    8395.947368   3127.736842   1974.315789   2506.421053   1268.552632
# std    16393.663202   6347.046718   4719.315348   5359.581996   3320.501425
# min       23.000000      3.000000      3.000000      3.000000      3.000000
# 25%      138.000000     41.500000     23.750000     46.500000     13.500000
# 50%     1150.500000    476.500000    229.500000    327.000000     77.500000
# 75%     5212.000000   1873.750000    668.500000   1257.250000    460.750000
# max    67430.000000  28061.000000  25380.000000  24507.000000  18734.000000
#
#                  대전            울산           세종        경기 고양       경기 과천  ...  \
# count     38.000000     38.000000    38.000000    38.000000   38.000000  ...
# mean    1234.315789    961.342105   128.052632   752.026316   46.868421  ...
# ...

# %%
df.columns
# Out:
# Index(['범죄대분류', '범죄중분류', '서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종',
#        '경기 고양', '경기 과천', '경기 광명', '경기 광주', '경기 구리', '경기 군포', '경기 김포', '경기 남양주',
#        '경기 동두천', '경기 부천', '경기 성남', '경기 수원', '경기 시흥', '경기 안산', '경기 안성', '경기 안양',
#        '경기 양주', '경기 여주', '경기 오산', '경기 용인', '경기 의왕', '경기 의정부', '경기 이천', '경기 파주',
#        '경기 평택', '경기 포천', '경기 하남', '경기 화성', '강원 강릉', '강원 동해', '강원 삼척', '강원 속초',
#        '강원 원주', '강원 춘천', '강원 태백', '충북 제천', '충북 청주', '충북 충주', '충남 계룡', '충남 공주',
#        '충남 논산', '충남 당진', '충남 보령', '충남 서산', '충남 아산', '충남 천안', '전북 군산', '전북 김제',
#        '전북 남원', '전북 익산', '전북 전주', '전북 정읍', '전남 광양', '전남 나주', '전남 목포', '전남 순천',
#        '전남 여수', '경북 경산', '경북 경주', '경북 구미', '경북 김천', '경북 문경', '경북 상주', '경북 안동',
#        '경북 영주', '경북 영천', '경북 포항', '경남 거제', '경남 김해', '경남 밀양', '경남 사천', '경남 양산',
#        '경남 진주', '경남 창원', '경남 통영', '제주 서귀포', '제주 제주', '기타도시', '도시이외'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=38, step=1)

# %%
df_.shape
# Out:
# (31891, 22)

# %%
df_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31891 entries, 0 to 31890
# Data columns (total 22 columns):
# 안전비상벨관리번호      31891 non-null object
# 설치목적           31891 non-null int64
# 설치장소유형         31891 non-null int64
# 설치위치           31891 non-null object
# 소재지도로명주소       22950 non-null object
# 소재지지번주소        27134 non-null object
# 위도             31891 non-null float64
# 경도             31891 non-null float64
# 연계방식           31891 non-null int64
# 경찰연계유무         31891 non-null object
# 경비업체연계유무       31891 non-null object
# 관리사무소연계유무      31891 non-null object
# 부가기능           24052 non-null object
# 안전비상벨설치년도      31891 non-null int64
# 최종점검일자         31891 non-null object
# 최종점검결과구분       31891 non-null object
# 관리기관명          31891 non-null object
# 관리기관전화번호       31891 non-null object
# 데이터기준일자        31891 non-null object
# 제공기관코드         31891 non-null object
# 제공기관명          31891 non-null object
# Unnamed: 21    0 non-null float64
# ...

# %%
df_.describe()
# Out:
#                설치목적        설치장소유형            위도            경도          연계방식  \
# count  31891.000000  31891.000000  31891.000000  31891.000000  31891.000000
# mean       2.548148     31.190618     37.267826    127.113955      2.879558
# std       11.926156     43.326648      0.636747      0.517525      0.405140
# min        1.000000      1.000000     32.531290    123.774740      1.000000
# 25%        1.000000      2.000000     37.327134    126.871675      3.000000
# 50%        1.000000      5.000000     37.481832    127.008150      3.000000
# 75%        1.000000     99.000000     37.557171    127.131206      3.000000
# max       99.000000     99.000000     38.499644    130.257252      3.000000
#
#           안전비상벨설치년도  Unnamed: 21
# count  31891.000000          0.0
# mean    2014.526387          NaN
# std        3.112798          NaN
# min     2004.000000          NaN
# 25%     2013.000000          NaN
# 50%     2015.000000          NaN
# 75%     2017.000000          NaN
# ...

# %%
df_.columns
# Out:
# Index(['안전비상벨관리번호', '설치목적', '설치장소유형', '설치위치', '소재지도로명주소', '소재지지번주소', '위도',
#        '경도', '연계방식', '경찰연계유무', '경비업체연계유무', '관리사무소연계유무', '부가기능', '안전비상벨설치년도',
#        '최종점검일자', '최종점검결과구분', '관리기관명', '관리기관전화번호', '데이터기준일자', '제공기관코드', '제공기관명',
#        'Unnamed: 21'],
#       dtype='object')

# %%
df_.index
# Out:
# RangeIndex(start=0, stop=31891, step=1)

# %%
del df['범죄중분류']

# %%
df
# Out:
#      범죄대분류     서울     부산     대구     인천     광주     대전     울산    세종  경기 고양  ...  \
# 0     강력범죄     50     21     16     11      3      8      5     1      4  ...
# 1     강력범죄     91     41     30     24      6     14     12     5      5  ...
# 2     강력범죄    167    102     37     73     33     41     25     3     14  ...
# 3     강력범죄   1155    334    201    352    203    176     97    17     77  ...
# 4     강력범죄    144     43     26     44     23     33      2     0      5  ...
# 5     강력범죄   5582   1282    610   1282    490    481    302    53    258  ...
# 6     강력범죄     60     23      8     13     10      9      9     2      1  ...
# 7     강력범죄    225     90     71     81     35     37     33     3     27  ...
# 8     절도범죄  41144  15807   8310   9216   4821   6216   3578   582   2488  ...
# 9     폭력범죄   6016   4220   2781   2074   1171   1165   1409   152    540  ...
# 10    폭력범죄  36312  10174   6885  11586   4856   5256   3863   285   2917  ...
# ...

# %%
df1=df.groupby('범죄대분류').sum()

# %%
df1
# Out:
#            서울     부산     대구     인천     광주     대전     울산    세종  경기 고양  경기 과천  \
# 범죄대분류
# 강력범죄     7474   1936    999   1880    803    799    485    84    391     29
# 교통범죄    67430  28061  25380  24507  18734  14695  11264  1322   9681    672
# 기타범죄    42994  16779   8689  17000   4624   5191   5394   578   3501    228
# 노동범죄      587    228    371     55     12    143    104     4     26      1
# 마약범죄     1746    971    258    586     31     97     73    19    105      3
# 병역범죄     3735    593    568   1183    268    447    212   111    411     10
# 보건범죄     3606   1519    321    644    279    188    152    10    214     13
# 선거범죄      141     39     23     54     18     10     21     1      6      1
# 안보범죄       23      3      3      3      5      1      3     2      1      0
# 절도범죄    41144  15807   8310   9216   4821   6216   3578   582   2488    202
# 지능범죄    70294  23726  13206  16147   8401   8434   6426  1131   5561    310
# ...

# %%
df1.sum(axis=0)
# Out:
# 서울        319046
# 부산        118854
# 대구         75024
# 인천         95244
# 광주         48205
#            ...
# 경남 통영       5613
# 제주 서귀포      8385
# 제주 제주      24885
# 기타도시        3772
# 도시이외       99169
# Length: 87, dtype: int64

# %%
df_select=pd.DataFrame(df1.sum(axis=0))

# %%
df_select
# Out:
#              0
# 서울      319046
# 부산      118854
# 대구       75024
# 인천       95244
# 광주       48205
# ...        ...
# 경남 통영     5613
# 제주 서귀포    8385
# 제주 제주    24885
# 기타도시      3772
# 도시이외     99169
#
# [87 rows x 1 columns]

# %%
df_select.index
# Out:
# Index(['서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기 고양', '경기 과천',
#        '경기 광명', '경기 광주', '경기 구리', '경기 군포', '경기 김포', '경기 남양주', '경기 동두천',
#        '경기 부천', '경기 성남', '경기 수원', '경기 시흥', '경기 안산', '경기 안성', '경기 안양', '경기 양주',
#        '경기 여주', '경기 오산', '경기 용인', '경기 의왕', '경기 의정부', '경기 이천', '경기 파주', '경기 평택',
#        '경기 포천', '경기 하남', '경기 화성', '강원 강릉', '강원 동해', '강원 삼척', '강원 속초', '강원 원주',
#        '강원 춘천', '강원 태백', '충북 제천', '충북 청주', '충북 충주', '충남 계룡', '충남 공주', '충남 논산',
#        '충남 당진', '충남 보령', '충남 서산', '충남 아산', '충남 천안', '전북 군산', '전북 김제', '전북 남원',
#        '전북 익산', '전북 전주', '전북 정읍', '전남 광양', '전남 나주', '전남 목포', '전남 순천', '전남 여수',
#        '경북 경산', '경북 경주', '경북 구미', '경북 김천', '경북 문경', '경북 상주', '경북 안동', '경북 영주',
#        '경북 영천', '경북 포항', '경남 거제', '경남 김해', '경남 밀양', '경남 사천', '경남 양산', '경남 진주',
#        '경남 창원', '경남 통영', '제주 서귀포', '제주 제주', '기타도시', '도시이외'],
#       dtype='object')

# %%
df_select.columns
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
df_select=df_select.rename(columns={0:'범죄발생건수'})

# %%
df_select
# Out:
#         범죄발생건수
# 서울      319046
# 부산      118854
# 대구       75024
# 인천       95244
# 광주       48205
# ...        ...
# 경남 통영     5613
# 제주 서귀포    8385
# 제주 제주    24885
# 기타도시      3772
# 도시이외     99169
#
# [87 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib import font_manager, rc
import matplotlib
font_location="C:\Windows\Fonts\malgun.ttf"
font_name=font_manager.FontProperties(fname=font_location).get_name()
matplotlib.rc('font',family=font_name)

# %%
plt.figure(figsize=(15, 9))
plt.plot(df_select.iloc[0:15])

# %%
type(df_select['범죄발생건수'][0])
# Out:
# numpy.int64

# %%
df_select.sort_values(by='범죄발생건수').head()
# Out:
#        범죄발생건수
# 충남 계룡     419
# 강원 태백    1233
# 경기 과천    1781
# 경북 문경    1885
# 전북 남원    2269

# %%
df_select.sort_values(by='범죄발생건수', ascending=False).head()
# Out:
#       범죄발생건수
# 서울    319046
# 부산    118854
# 도시이외   99169
# 인천     95244
# 대구     75024

# %%
df_select_for_graph=df_select.sort_values(by='범죄발생건수', ascending=False).head()

# %%
df_select_for_graph
# Out:
#       범죄발생건수
# 서울    319046
# 부산    118854
# 도시이외   99169
# 인천     95244
# 대구     75024

# %%
plt.bar(df_select_for_graph.index,df_select_for_graph['범죄발생건수'])
# Out:
# <BarContainer object of 5 artists>

# %%
df_seoul=df1['서울'].reset_index()

# %%
df_seoul
# Out:
#      범죄대분류     서울
# 0     강력범죄   7474
# 1     교통범죄  67430
# 2     기타범죄  42994
# 3     노동범죄    587
# 4     마약범죄   1746
# 5     병역범죄   3735
# 6     보건범죄   3606
# 7     선거범죄    141
# 8     안보범죄     23
# 9     절도범죄  41144
# 10    지능범죄  70294
# 11  특별경제범죄  15101
# 12    폭력범죄  59401
# 13    풍속범죄   5318
# 14    환경범죄     52

# %%
df1['서울'].sort_values(ascending=False)
# Out:
# 범죄대분류
# 지능범죄      70294
# 교통범죄      67430
# 폭력범죄      59401
# 기타범죄      42994
# 절도범죄      41144
# 특별경제범죄    15101
# 강력범죄       7474
# 풍속범죄       5318
# 병역범죄       3735
# 보건범죄       3606
# 마약범죄       1746
# 노동범죄        587
# 선거범죄        141
# 환경범죄         52
# 안보범죄         23
# Name: 서울, dtype: int64

# %%
plt.figure(figsize=(12, 8))
plt.plot(df_seoul['범죄대분류'], df_seoul['서울'])

# %%
plt.barh(df_seoul['범죄대분류'], df_seoul['서울'])
# Out:
# <BarContainer object of 15 artists>

# %%
plt.figure(figsize=(15, 9))

plt.plot(df1['서울'], label='서울')
plt.plot(df1['부산'], label='부산')
plt.plot(df1['도시이외'], label='도시이외')

plt.legend()

plt.show();

# %%
df_['소재지지번주소']
# Out:
# 0             대전광역시 중구 어남동 248-1
# 1              대전광역시 중구 무수동 96-3
# 2            대전광역시 중구 은행동 170-31
# 3               대전광역시 중구 선화동 139
# 4              대전광역시 중구 은행동 4-87
#                   ...
# 31886         경상북도 경산시 중방동 683-1
# 31887         경상북도 경산시 옥산동 739-2
# 31888           경상북도 경산시 옥산동 872
# 31889         경상북도 경산시 백천동 551-9
# 31890    경상북도 경산시 하양읍 금락리 135-61
# Name: 소재지지번주소, Length: 31891, dtype: object

# %%
df_seoul_bell=df_[df_['소재지지번주소'].str.contains('서울특별시', na=False)]

# %%
df_busan_bell=df_[df_['소재지지번주소'].str.contains('부산광역시', na=False)]

# %%
df_incheon_bell=df_[df_['소재지지번주소'].str.contains('인천광역시', na=False)]

# %%
df_seoul_bell
# Out:
#           안전비상벨관리번호  설치목적  설치장소유형                  설치위치  \
# 35                1     1       1           고척근린공원 게이트볼
# 36                2     1       1            고척근린공원 주차장
# 37                3     1       1      고척근린공원 놀이터(상상공원)
# 38                4     1       1        절골어린이공원 어린이놀이터
# 39                5     1      99          구일초교 1지점 회전형
# ...             ...   ...     ...                   ...
# 29888  스쿨존-천호3동-001     1       5  천호3동 53-19 화랑유치원 마트앞
# 29889  스쿨존-천호3동-002     1       5   천호3동 53-31 화랑유치원 정문
# 29890  스쿨존-천호3동-003     1       5  천호3동 551-7 강동복지관어린이집
# 29891  스쿨존-천호3동-004     1       5     천호3동 186-7 예은어린이집
# 29892  스쿨존-천호3동-005     1       5    천호3동 55-17 도로변 사거리
#
#                         소재지도로명주소                 소재지지번주소         위도  \
# 35           서울특별시 구로구 고척로45길 39     서울특별시 구로구 고척동 산9-14  37.506582
# 36           서울특별시 구로구 고척로45길 39     서울특별시 구로구 고척동 산9-14  37.506582
# 37           서울특별시 구로구 고척로45길 39     서울특별시 구로구 고척동 산9-14  37.506582
# ...

# %%
df_seoul_bell.head()
# Out:
#    안전비상벨관리번호  설치목적  설치장소유형              설치위치               소재지도로명주소  \
# 35         1     1       1       고척근린공원 게이트볼    서울특별시 구로구 고척로45길 39
# 36         2     1       1        고척근린공원 주차장    서울특별시 구로구 고척로45길 39
# 37         3     1       1  고척근린공원 놀이터(상상공원)    서울특별시 구로구 고척로45길 39
# 38         4     1       1    절골어린이공원 어린이놀이터  서울특별시 구로구 개봉로3가길 88-9
# 39         5     1      99      구일초교 1지점 회전형       서울특별시 구로구 구일로 68
#
#                    소재지지번주소         위도          경도  연계방식 경찰연계유무  ...  부가기능  \
# 35     서울특별시 구로구 고척동 산9-14  37.506582  126.853278     3      N  ...  CCTV
# 36     서울특별시 구로구 고척동 산9-14  37.506582  126.853278     3      N  ...  CCTV
# 37     서울특별시 구로구 고척동 산9-14  37.506582  126.853278     3      N  ...  CCTV
# 38   서울특별시 구로구 개봉3동 312-25  37.482893  126.851798     3      N  ...  CCTV
# 39  서울특별시 구로구 구로1동 685-221  37.492795  126.872927     3      N  ...  CCTV
#
#    안전비상벨설치년도      최종점검일자  최종점검결과구분 관리기관명     관리기관전화번호     데이터기준일자   제공기관코드  \
# ...

# %%
# !pip install plotnine==0.5.0
# !pip install –upgrade pandas==0.23.4
# !pip install folium==0.5.0
# !pip install statsmodels -U
# %matplotlib inline

import plotnine
# Out:
# Traceback (most recent call last):
#   File "C:\Users\yangyoungjo\Anaconda3\Scripts\pip-script.py", line 10, in <module>
#     sys.exit(main())
# TypeError: 'module' object is not callable
# Traceback (most recent call last):
#   File "C:\Users\yangyoungjo\Anaconda3\Scripts\pip-script.py", line 10, in <module>
#     sys.exit(main())
# TypeError: 'module' object is not callable
# Traceback (most recent call last):
#   File "C:\Users\yangyoungjo\Anaconda3\Scripts\pip-script.py", line 10, in <module>
#     sys.exit(main())
# TypeError: 'module' object is not callable
# Traceback (most recent call last):
#   File "C:\Users\yangyoungjo\Anaconda3\Scripts\pip-script.py", line 10, in <module>
#     sys.exit(main())
# TypeError: 'module' object is not callable

# %%
from matplotlib import font_manager, rc
font_location='c:/Windows/fonts/malgun.ttf'
font_name=font_manager.FontProperties(fname=font_location).get_name()
from plotnine import *

# %%
(ggplot(df_seoul_bell)
+ aes(x='경도', y='위도', color='제공기관명')
+ geom_point()
+ theme(text=element_text(family=font_name))
)
# Out:
# C:\Users\yangyoungjo\Anaconda3\lib\site-packages\plotnine\scales\scale.py:93: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(self.breaks) and cbook.iterable(self.labels):
# C:\Users\yangyoungjo\Anaconda3\lib\site-packages\plotnine\utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# <ggplot: (164986196449)>

# %%
(ggplot(df_busan_bell)
+ aes(x='경도', y='위도', color='제공기관명')
+ geom_point()
+ theme(text=element_text(family=font_name))
)
# Out:
# C:\Users\yangyoungjo\Anaconda3\lib\site-packages\plotnine\scales\scale.py:93: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(self.breaks) and cbook.iterable(self.labels):
# C:\Users\yangyoungjo\Anaconda3\lib\site-packages\plotnine\utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# <ggplot: (164981469837)>

# %%
(ggplot(df_incheon_bell)
+ aes(x='경도', y='위도', color='제공기관명')
+ geom_point()
+ theme(text=element_text(family=font_name))
)
# Out:
# C:\Users\yangyoungjo\Anaconda3\lib\site-packages\plotnine\scales\scale.py:93: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(self.breaks) and cbook.iterable(self.labels):
# C:\Users\yangyoungjo\Anaconda3\lib\site-packages\plotnine\utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# <ggplot: (164986232787)>
